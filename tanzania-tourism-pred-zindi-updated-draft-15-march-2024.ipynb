# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tanzania-tourism-prediction/SampleSubmission (7).csv
# /kaggle/input/tanzania-tourism-prediction/Test (7).csv
# /kaggle/input/tanzania-tourism-prediction/Train (14).csv

# %%
train=pd.read_csv('/kaggle/input/tanzania-tourism-prediction/Train (14).csv')
train
# Out:
#              ID                   country age_group        travel_with  \
# 0        tour_0                SWIZERLAND     45-64  Friends/Relatives
# 1       tour_10            UNITED KINGDOM     25-44                NaN
# 2     tour_1000            UNITED KINGDOM     25-44              Alone
# 3     tour_1002            UNITED KINGDOM     25-44             Spouse
# 4     tour_1004                     CHINA      1-24                NaN
# ...         ...                       ...       ...                ...
# 4804   tour_993                       UAE     45-64              Alone
# 4805   tour_994  UNITED STATES OF AMERICA     25-44             Spouse
# 4806   tour_995               NETHERLANDS      1-24                NaN
# 4807   tour_997              SOUTH AFRICA     25-44  Friends/Relatives
# 4808   tour_999            UNITED KINGDOM     25-44             Spouse
#
#       total_female  total_male                         purpose  \
# ...

# %%
import seaborn as sns 
sns.displot(np.log(train["total_cost"]))
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.distplot((train["total_cost"]**(1/3)))
# Out:
# /tmp/ipykernel_33/2341273369.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((train["total_cost"]**(1/3)))
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_cost', ylabel='Density'>

# %%
test=pd.read_csv("/kaggle/input/tanzania-tourism-prediction/Test (7).csv")
test
# Out:
#              ID                   country age_group          travel_with  \
# 0        tour_1                 AUSTRALIA     45-64               Spouse
# 1      tour_100              SOUTH AFRICA     25-44    Friends/Relatives
# 2     tour_1001                   GERMANY     25-44    Friends/Relatives
# 3     tour_1006                    CANADA    24-Jan    Friends/Relatives
# 4     tour_1009            UNITED KINGDOM     45-64    Friends/Relatives
# ...         ...                       ...       ...                  ...
# 1596   tour_988  UNITED STATES OF AMERICA     25-44                  NaN
# 1597   tour_990                     ITALY     45-64  Spouse and Children
# 1598   tour_992                   FINLAND     25-44                Alone
# 1599   tour_996              SOUTH AFRICA    24-Jan                Alone
# 1600   tour_998              SOUTH AFRICA     25-44               Spouse
#
#       total_female  total_male                  purpose      main_activity  \
# ...

# %%
all_data=pd.concat([train,test])
all_data
# Out:
#              ID                   country age_group          travel_with  \
# 0        tour_0                SWIZERLAND     45-64    Friends/Relatives
# 1       tour_10            UNITED KINGDOM     25-44                  NaN
# 2     tour_1000            UNITED KINGDOM     25-44                Alone
# 3     tour_1002            UNITED KINGDOM     25-44               Spouse
# 4     tour_1004                     CHINA      1-24                  NaN
# ...         ...                       ...       ...                  ...
# 1596   tour_988  UNITED STATES OF AMERICA     25-44                  NaN
# 1597   tour_990                     ITALY     45-64  Spouse and Children
# 1598   tour_992                   FINLAND     25-44                Alone
# 1599   tour_996              SOUTH AFRICA    24-Jan                Alone
# 1600   tour_998              SOUTH AFRICA     25-44               Spouse
#
#       total_female  total_male                         purpose  \
# ...

# %%
train['age_group'].unique()
# Out:
# array(['45-64', '25-44', '1-24', '65+'], dtype=object)

# %%
all_data2=all_data.drop(columns=["ID","total_cost"])
all_data2
# Out:
#                        country age_group          travel_with  total_female  \
# 0                   SWIZERLAND     45-64    Friends/Relatives           1.0
# 1               UNITED KINGDOM     25-44                  NaN           1.0
# 2               UNITED KINGDOM     25-44                Alone           0.0
# 3               UNITED KINGDOM     25-44               Spouse           1.0
# 4                        CHINA      1-24                  NaN           1.0
# ...                        ...       ...                  ...           ...
# 1596  UNITED STATES OF AMERICA     25-44                  NaN           0.0
# 1597                     ITALY     45-64  Spouse and Children           3.0
# 1598                   FINLAND     25-44                Alone           0.0
# 1599              SOUTH AFRICA    24-Jan                Alone           0.0
# 1600              SOUTH AFRICA     25-44               Spouse           1.0
#
# ...

# %%
cat=all_data2.columns[all_data2.dtypes==object]
cat

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat:
    all_data2[i]=le.fit_transform(all_data2[i])
    
all_data2
# Out:
#       country  age_group  travel_with  total_female  total_male  purpose  \
# 0         101          3            2           1.0         1.0        1
# 1         111          2            5           1.0         0.0        1
# 2         111          2            0           0.0         1.0        5
# 3         111          2            3           1.0         1.0        1
# 4          17          0            5           1.0         0.0        1
# ...       ...        ...          ...           ...         ...      ...
# 1596      112          2            5           0.0         1.0        2
# 1597       47          3            4           3.0         1.0        1
# 1598       32          2            0           0.0         1.0        2
# 1599       95          1            0           0.0         1.0        0
# 1600       95          2            3           1.0         1.0        1
#
#       main_activity  info_source  tour_arrangement  package_transport_int  \
# ...

# %%
all_data2=all_data2.fillna(0)

# %%
train_2=all_data2[:len(train)]
test_2=all_data2[len(train):]
train_2
# Out:
#       country  age_group  travel_with  total_female  total_male  purpose  \
# 0         101          3            2           1.0         1.0        1
# 1         111          2            5           1.0         0.0        1
# 2         111          2            0           0.0         1.0        5
# 3         111          2            3           1.0         1.0        1
# 4          17          0            5           1.0         0.0        1
# ...       ...        ...          ...           ...         ...      ...
# 4804      107          3            0           0.0         1.0        0
# 4805      112          2            3           1.0         1.0        1
# 4806       73          0            5           1.0         0.0        1
# 4807       95          2            2           1.0         1.0        0
# 4808      111          2            3           1.0         1.0        1
#
#       main_activity  info_source  tour_arrangement  package_transport_int  \
# ...

# %%
#k-fold 교차검증 
from sklearn.model_selection import StratifiedKFold
skf=StratifiedKFold(n_splits=5,shuffle=True,random_state=42)

# %%
from sklearn.model_selection import KFold
from catboost import CatBoostRegressor

# KFold 인스턴스 생성
kf = KFold(n_splits=5, shuffle=True, random_state=42)

result = 0
best_score = 0
cbc = CatBoostRegressor(learning_rate=0.06,verbose=100)

for train_index, valid_index in kf.split(train_2):
    x_train = train_2.iloc[train_index]
    x_valid = train_2.iloc[valid_index]
    # 타겟 변수에 로그 변환 적용
    #y_train = np.log(train['total_cost'].iloc[train_index])
    y_train =(train["total_cost"]**(1/3)).iloc[train_index]
    y_valid = (train["total_cost"]**(1/3)).iloc[valid_index]
    #y_valid = np.log(train['total_cost'].iloc[valid_index])
    cbc.fit(x_train, y_train, eval_set=(x_valid, y_valid), early_stopping_rounds=50)
    # 예측 값에 역변환 적용
    result += (cbc.predict(test_2))**(3) / 5
    #result += np.exp(cbc.predict(test_2)) / 5

result
# Out:
# 0:	learn: 82.3072588	test: 80.4351644	best: 80.4351644 (0)	total: 2.09ms	remaining: 2.09s
# 100:	learn: 52.5943388	test: 55.3144576	best: 55.3144576 (100)	total: 172ms	remaining: 1.53s
# 200:	learn: 49.6100945	test: 54.8367270	best: 54.8110775 (194)	total: 350ms	remaining: 1.39s
# 300:	learn: 47.3033427	test: 54.7760335	best: 54.7587070 (282)	total: 503ms	remaining: 1.17s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 54.72913306
# bestIteration = 315
#
# Shrink model to first 316 iterations.
# 0:	learn: 82.4218786	test: 79.9749667	best: 79.9749667 (0)	total: 1.98ms	remaining: 1.98s
# 100:	learn: 52.4959271	test: 54.5552445	best: 54.5552445 (100)	total: 199ms	remaining: 1.77s
# 200:	learn: 49.6538573	test: 54.1298524	best: 54.1162506 (196)	total: 380ms	remaining: 1.51s
# 300:	learn: 47.2978739	test: 53.8626587	best: 53.8402218 (271)	total: 584ms	remaining: 1.36s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 53.84022184
# ...

# %%
sub=pd.read_csv("/kaggle/input/tanzania-tourism-prediction/SampleSubmission (7).csv")
sub
# Out:
#              ID  total_cost
# 0        tour_1           0
# 1      tour_100           0
# 2     tour_1001           0
# 3     tour_1006           0
# 4     tour_1009           0
# ...         ...         ...
# 1596   tour_988           0
# 1597   tour_990           0
# 1598   tour_992           0
# 1599   tour_996           0
# 1600   tour_998           0
#
# [1601 rows x 2 columns]

# %%
sub["total_cost"]=result
sub
# Out:
#              ID    total_cost
# 0        tour_1  1.775844e+07
# 1      tour_100  7.314050e+06
# 2     tour_1001  1.032284e+07
# 3     tour_1006  2.565494e+06
# 4     tour_1009  1.954956e+07
# ...         ...           ...
# 1596   tour_988  4.184527e+05
# 1597   tour_990  1.981303e+07
# 1598   tour_992  1.107066e+06
# 1599   tour_996  5.371929e+05
# 1600   tour_998  4.777612e+06
#
# [1601 rows x 2 columns]

# %%
sub.to_csv("sub123.csv",index=0)

# %% [markdown]
# ## 14/208 as of 15 March 2024
# ![image.png](attachment:8169c8a1-7fdc-45d2-8c08-90d40840c475.png)
